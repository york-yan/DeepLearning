# %% [markdown]
# # 多通道输入输出
# ![image.png](attachment:image.png)
# # 1×1卷积层
# 1×1卷积层用在通道计算之上

# %% [markdown]
# # 池化层 pooling
# ## 最大池化层
# ![image.png](attachment:image.png)
# ## 平均池化层

# %%
import torch 
from torch import nn

x=torch.rand((1,1,8,8))
print(x)
maxpool=nn.MaxPool2d(2)
avgpool=nn.AvgPool2d(2)

print(maxpool(x))
print(avgpool(x))
# Out:
# tensor([[[[0.6038, 0.6443, 0.6606, 0.4444, 0.0791, 0.3807, 0.6858, 0.1817],
#           [0.3041, 0.9283, 0.4127, 0.1196, 0.0869, 0.3731, 0.8184, 0.7230],
#           [0.5226, 0.8861, 0.8024, 0.2875, 0.6249, 0.3512, 0.5035, 0.7434],
#           [0.9802, 0.4659, 0.6585, 0.3623, 0.2760, 0.8844, 0.8516, 0.4492],
#           [0.0669, 0.1311, 0.4760, 0.4496, 0.4863, 0.1343, 0.0733, 0.4081],
#           [0.1380, 0.3006, 0.8301, 0.2459, 0.0347, 0.1949, 0.4970, 0.8442],
#           [0.8517, 0.2166, 0.7717, 0.8913, 0.5357, 0.5096, 0.5046, 0.7411],
#           [0.1511, 0.2836, 0.0765, 0.9466, 0.4530, 0.9951, 0.2086, 0.6883]]]])
# tensor([[[[0.9283, 0.6606, 0.3807, 0.8184],
#           [0.9802, 0.8024, 0.8844, 0.8516],
#           [0.3006, 0.8301, 0.4863, 0.8442],
#           [0.8517, 0.9466, 0.9951, 0.7411]]]])
# tensor([[[[0.6201, 0.4093, 0.2299, 0.6022],
#           [0.7137, 0.5277, 0.5341, 0.6369],
#           [0.1591, 0.5004, 0.2126, 0.4557],
#           [0.3758, 0.6715, 0.6234, 0.5357]]]])
